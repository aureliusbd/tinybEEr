# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
actual = np.array([32,69,98,212])
error = np.array([-0.4649, 0.0136644, -0.2026,-0.0652])

print(actual)
# Out:
# [ 32  69  98 212]

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a1         float64    77.31456832142138
# actual     ndarray    4: 4 elems, type `int64`, 32 bytes
# b1         float64    67.94354281262878
# error      ndarray    4: 4 elems, type `float64`, 32 bytes
# np         module     <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# x1         list       n=2
# y1         list       n=2

# %%
plt.scatter(x = actual, y = error)

# %%
#find line of best fit
y1 = np.array([-0.4649, 0.0136644])
x1 = np.array([32,69])
a1, b1 = np.polyfit(x1, y1, 1)

#add points to plot
plt.scatter( x = x1, y = y1)

#add line of best fit to plot
plt.plot(x1, a1*x1+b1)

# %%
print(a1, b1)
# Out:
# 0.01293417297297297 -0.8787935351351349

# %%
x2 = np.array([69,98])
y2= np.array([0.0136644, -0.2026])
a2, b2 = np.polyfit(x2, y2, 1)

#add points to plot
plt.scatter( x = x2, y = y2)

#add line of best fit to plot
plt.plot(x2, a2*x2+b2)

# %%
print(a2, b2)
# Out:
# -0.007457393103448269 0.5282245241379304

# %%
x3 = np.array([98,212])
y3 = np.array([-0.2026,-0.0652])

a3, b3 = np.polyfit(x3, y3, 1)

#add points to plot
plt.scatter( x = x3, y = y3)

#add line of best fit to plot
plt.plot(x3, a3*x3+b3)

# %%
print(a3, b3)
# Out:
# 0.0012052631578947366 -0.32071578947368407
